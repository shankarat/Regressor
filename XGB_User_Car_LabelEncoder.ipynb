# %% [markdown]
# # Used Cars Price Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# preprocessing
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, StratifiedKFold
import pandas_profiling as pp

# models
from sklearn.model_selection import cross_val_predict as cvp
from sklearn import metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import xgboost as xgb



import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read datasets

# %%
df = pd.read_csv(r'vehicles_data.csv')
df.head(5)
# Out:
#    Unnamed: 0          id                                                url  \
# 0       55483  7315914053  https://sandiego.craigslist.org/esd/ctd/d/el-c...
# 1      162368  7310885048  https://omaha.craigslist.org/ctd/d/omaha-2017-...
# 2      234393  7308243856  https://charlotte.craigslist.org/ctd/d/charlot...
# 3      276110  7315817729  https://newyork.craigslist.org/brk/ctd/d/passa...
# 4      349033  7301620999  https://greenville.craigslist.org/ctd/d/newry-...
#
#                    region                         region_url  price    year  \
# 0               san diego    https://sandiego.craigslist.org      0  2018.0
# 1  omaha / council bluffs       https://omaha.craigslist.org  13995  2017.0
# 2               charlotte   https://charlotte.craigslist.org  19990  2019.0
# 3           new york city     https://newyork.craigslist.org      0  2019.0
# 4    greenville / upstate  https://greenville.craigslist.org  42900  2015.0
#
#   manufacturer             model  condition  ... size         type  \
# 0          ram    promaster 2500  excellent  ...  NaN          van
# 1        mazda              cx-3        NaN  ...  NaN          SUV
# 2   mitsubishi  eclipse cross sp       good  ...  NaN    hatchback
# 3        honda              cr-v        NaN  ...  NaN          SUV
# 4    chevrolet          corvette  excellent  ...  NaN  convertible
#
#    paint_color                                          image_url  \
# 0          NaN  https://images.craigslist.org/00101_7UYL6JvF6q...
# 1        white  https://images.craigslist.org/00t0t_2tlVeJAW5Z...
# 2        white  https://images.craigslist.org/00000_3c4A3S9r5d...
# 3       orange  https://images.craigslist.org/00A0A_8tKj1EDSRK...
# 4        black  https://images.craigslist.org/00w0w_8pj8aAH74G...
#
#                                          description county state        lat  \
# 0  East County Pre-Owned Superstore provides a 10...    NaN    ca  32.792800
# 1  2017 *Mazda* *CX-3* Sport AWD SUV - $13,995CAL...    NaN    ia  41.207382
# 2  Carvana is the safer way to buy a car During t...    NaN    nc  35.190000
# 3  2019 Honda CR-V EX AWD     Offered by: NASA AU...    NaN    ny  40.854573
# 4  Video link below!!! Stunning 2015 Chevrolet Co...    NaN    sc  34.755562
#
#          long              posting_date
# 0 -116.966500  2021-05-02T13:30:34-0700
# 1  -96.023096  2021-04-22T11:20:19-0500
# 2  -80.830000  2021-04-17T11:11:13-0400
# 3  -74.120219  2021-05-02T13:24:50-0400
# 4  -82.906419  2021-04-04T09:18:23-0400
#
# [5 rows x 27 columns]

# %%
drop_columns = ['Unnamed: 0','id','url','region','region_url', 'title_status', 'VIN', 'size', 'image_url', 'lat','long','county','description','posting_date']
df = df.drop(columns = drop_columns,axis=1)

# %%
df.shape
# Out:
# (64032, 13)

# %%
df.isna().sum()
# Out:
# price               0
# year              158
# manufacturer     2569
# model             802
# condition       26097
# cylinders       26511
# fuel              424
# odometer          669
# transmission      353
# drive           19471
# type            13785
# paint_color     19505
# state               0
# dtype: int64

# %%
df = df.dropna()
df.head(5)
# Out:
#     price    year manufacturer                       model  condition  \
# 5       0  2006.0     chrysler                         300   like new
# 9   20995  2011.0    chevrolet              silverado 1500  excellent
# 15  50995  2017.0          gmc                yukon denali   like new
# 22  13500  2014.0    chevrolet                       tahoe       good
# 29  34990  2016.0          gmc  canyon crew cab sle pickup       good
#
#       cylinders fuel  odometer transmission drive    type paint_color state
# 5   8 cylinders  gas  149000.0    automatic   rwd   sedan       white    fl
# 9   8 cylinders  gas   92001.0    automatic   4wd   truck        blue    wi
# 15  8 cylinders  gas   70227.0    automatic   4wd     SUV        grey    ak
# 22  8 cylinders  gas   96007.0    automatic   rwd     SUV       white    fl
# 29  6 cylinders  gas   34425.0        other   4wd  pickup         red    ma

# %%
df.shape
# Out:
# (17491, 13)

# %%
df.describe()
# Out:
#               price          year      odometer
# count  1.749100e+04  17491.000000  1.749100e+04
# mean   1.632545e+04   2009.535247  1.122616e+05
# std    1.294429e+05      9.596493  2.155149e+05
# min    0.000000e+00   1918.000000  0.000000e+00
# 25%    5.600000e+03   2006.000000  5.578700e+04
# 50%    1.095000e+04   2012.000000  1.025670e+05
# 75%    2.250000e+04   2015.000000  1.480000e+05
# max    1.700000e+07   2022.000000  1.000000e+07

# %%
# Determination categorical features

numerics = ['int8', 'int16', 'int32', 'int64', 'float16', 'float32', 'float64']

categorical_columns = []

features = df.columns.values.tolist()

for col in features:
    if df[col].dtype in numerics: continue
    categorical_columns.append(col)
# Encoding categorical features
for col in categorical_columns:
    if col in df.columns:
        le = LabelEncoder()
        le.fit(list(df[col].astype(str).values))
        df[col] = le.transform(list(df[col].astype(str).values))

# %%
df.head()
# Out:
#     price    year  manufacturer  model  condition  cylinders  fuel  odometer  \
# 5       0  2006.0             7    161          3          6     2  149000.0
# 9   20995  2011.0             6   3351          0          6     2   92001.0
# 15  50995  2017.0            13   4147          3          6     2   70227.0
# 22  13500  2014.0             6   3653          2          6     2   96007.0
# 29  34990  2016.0            13    851          2          5     2   34425.0
#
#     transmission  drive  type  paint_color  state
# 5              0      2     9           10      9
# 9              0      0    10            1     48
# 15             0      0     0            5      0
# 22             0      2     0           10      9
# 29             2      0     8            8     19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17491 entries, 5 to 64031
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         17491 non-null  int64
#  1   year          17491 non-null  float64
#  2   manufacturer  17491 non-null  int64
#  3   model         17491 non-null  int64
#  4   condition     17491 non-null  int64
#  5   cylinders     17491 non-null  int64
#  6   fuel          17491 non-null  int64
#  7   odometer      17491 non-null  float64
#  8   transmission  17491 non-null  int64
#  9   drive         17491 non-null  int64
#  10  type          17491 non-null  int64
#  11  paint_color   17491 non-null  int64
#  12  state         17491 non-null  int64
# dtypes: float64(2), int64(11)
# memory usage: 1.9 MB

# %% [markdown]
# ### Selecting realistic data

# %%
df = df[df['price'] > 1000]
df = df[df['price'] < 40000]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15672 entries, 9 to 64031
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         15672 non-null  int64
#  1   year          15672 non-null  float64
#  2   manufacturer  15672 non-null  int64
#  3   model         15672 non-null  int64
#  4   condition     15672 non-null  int64
#  5   cylinders     15672 non-null  int64
#  6   fuel          15672 non-null  int64
#  7   odometer      15672 non-null  float64
#  8   transmission  15672 non-null  int64
#  9   drive         15672 non-null  int64
#  10  type          15672 non-null  int64
#  11  paint_color   15672 non-null  int64
#  12  state         15672 non-null  int64
# dtypes: float64(2), int64(11)
# memory usage: 1.7 MB

# %%
df.describe()
# Out:
#               price          year  manufacturer         model     condition  \
# count  15672.000000  15672.000000  15672.000000  15672.000000  15672.000000
# mean   14628.795559   2009.213502     17.586077   2110.262060      1.192637
# std    10522.984302      9.373542     11.115040   1195.354356      1.136227
# min     1100.000000   1918.000000      0.000000      1.000000      0.000000
# 25%     6200.000000   2006.000000      9.000000   1098.000000      0.000000
# 50%    10996.500000   2011.000000     13.000000   2066.000000      2.000000
# 75%    20995.500000   2015.000000     28.000000   3245.000000      2.000000
# max    39999.000000   2022.000000     39.000000   4186.000000      5.000000
#
#           cylinders         fuel      odometer  transmission         drive  \
# count  15672.000000  15672.00000  1.567200e+04  15672.000000  15672.000000
# mean       4.600881      1.95291  1.137207e+05      0.278139      0.829952
# std        1.263622      0.49251  1.745381e+05      0.639189      0.782515
# min        0.000000      0.00000  0.000000e+00      0.000000      0.000000
# 25%        3.000000      2.00000  6.179600e+04      0.000000      0.000000
# 50%        5.000000      2.00000  1.064245e+05      0.000000      1.000000
# 75%        6.000000      2.00000  1.500000e+05      0.000000      1.000000
# max        7.000000      4.00000  1.000000e+07      2.000000      2.000000
#
#                type   paint_color         state
# count  15672.000000  15672.000000  15672.000000
# mean       6.008486      5.575932     24.028905
# std        4.054207      4.002485     14.836002
# min        0.000000      0.000000      0.000000
# 25%        2.000000      1.000000      9.000000
# 50%        8.000000      6.000000     23.000000
# 75%        9.000000      9.000000     37.000000
# max       12.000000     11.000000     50.000000

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#                  price      year  manufacturer     model  condition  \
# price         1.000000  0.365629     -0.063317  0.044708   0.113452
# year          0.365629  1.000000      0.045193  0.046446   0.018426
# manufacturer -0.063317  0.045193      1.000000  0.013222  -0.027090
# model         0.044708  0.046446      0.013222  1.000000  -0.003162
# condition     0.113452  0.018426     -0.027090 -0.003162   1.000000
# cylinders     0.308654 -0.176830     -0.251570  0.080125   0.068665
# fuel         -0.043515  0.073875      0.023902  0.023951   0.043579
# odometer     -0.225551 -0.155168      0.017731  0.003002  -0.022735
# transmission  0.480890  0.120940     -0.004443 -0.010415   0.222409
# drive        -0.062936 -0.206506     -0.118914 -0.163773   0.049836
# type          0.035673  0.016615      0.006027 -0.106811   0.035288
# paint_color   0.055619  0.020187     -0.018046  0.008621   0.005069
# state        -0.003258  0.009275     -0.016123  0.025645   0.020690
#
#               cylinders      fuel  odometer  transmission     drive      type  \
# price          0.308654 -0.043515 -0.225551      0.480890 -0.062936  0.035673
# year          -0.176830  0.073875 -0.155168      0.120940 -0.206506  0.016615
# manufacturer  -0.251570  0.023902  0.017731     -0.004443 -0.118914  0.006027
# model          0.080125  0.023951  0.003002     -0.010415 -0.163773 -0.106811
# condition      0.068665  0.043579 -0.022735      0.222409  0.049836  0.035288
# cylinders      1.000000 -0.110999  0.018010      0.153805  0.015704  0.008297
# fuel          -0.110999  1.000000 -0.067270      0.128162  0.045451 -0.112580
# odometer       0.018010 -0.067270  1.000000     -0.137220 -0.016554 -0.001251
# transmission   0.153805  0.128162 -0.137220      1.000000  0.054125  0.000714
# drive          0.015704  0.045451 -0.016554      0.054125  1.000000  0.152097
# type           0.008297 -0.112580 -0.001251      0.000714  0.152097  1.000000
# paint_color    0.032810 -0.052829 -0.002651     -0.001010  0.072733  0.066838
# state          0.017029 -0.019516 -0.008964      0.000727 -0.066366 -0.012041
#
#               paint_color     state
# price            0.055619 -0.003258
# year             0.020187  0.009275
# manufacturer    -0.018046 -0.016123
# model            0.008621  0.025645
# condition        0.005069  0.020690
# cylinders        0.032810  0.017029
# fuel            -0.052829 -0.019516
# odometer        -0.002651 -0.008964
# transmission    -0.001010  0.000727
# drive            0.072733 -0.066366
# type             0.066838 -0.012041
# paint_color      1.000000 -0.015757
# state           -0.015757  1.000000

# %% [markdown]
# ## Data Scaling

# %%
y = df['price']
X = df.drop(['price'], axis=1)

# %%
# Synthesis test0 from train0
train_X, test_x, train_Y, test_y = train_test_split(X, y, test_size=0.25, random_state=10)

# %% [markdown]
# # XGB

# %%
import xgboost as xgb
xgb = xgb.XGBRegressor()

# %%
xgb.fit(train_X, train_Y)
# Out:
# [15:25:41] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
y_pred = xgb.predict(test_x)

# %%
r2_score(test_y,y_pred)
# Out:
# 0.8312090494420467
